# %% [markdown]
# #Entrega de Proyecto

# %% [markdown]
# 1- Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.

# %%
#Importamos PANDAS
import pandas as pd
import numpy as np
#Conexión con Drive (Montar)
from google.colab import drive
drive.mount('/content/drive')
#conexión con la ubicación de las carpeta donde se encuentra nuestro data ser
import os
os.listdir('/content/drive/MyDrive/datasets')
#lectura de archivos que nos interesan (Ventas.csv - clientes.csv - marketing.csv)
pd.read_csv('/content/drive/MyDrive/datasets/ventas.csv')
pd.read_csv('/content/drive/MyDrive/datasets/clientes.csv')
pd.read_csv('/content/drive/MyDrive/datasets/marketing.csv')
#Creamos el dataframe con las tablas Ventas-Clientes y Marketing
df_ventas = pd.read_csv('/content/drive/MyDrive/datasets/ventas.csv')
df_clientes = pd.read_csv('/content/drive/MyDrive/datasets/clientes.csv')
df_marketing = pd.read_csv('/content/drive/MyDrive/datasets/marketing.csv')
print(df_ventas)
print(df_clientes)
print(df_marketing)
# Out:
# Mounted at /content/drive
#       id_venta                producto   precio  cantidad fecha_venta  \
# 0          792       Cuadro decorativo   $69.94       5.0  02/01/2024
# 1          811         Lámpara de mesa  $105.10       5.0  02/01/2024
# 2         1156                Secadora   $97.96       3.0  02/01/2024
# 3         1372                Heladera  $114.35       8.0  02/01/2024
# 4         1546                Secadora  $106.21       4.0  02/01/2024
# ...        ...                     ...      ...       ...         ...
# 3030      1837         Horno eléctrico  $104.12       9.0  30/12/2024
# 3031      2276                  Laptop   $85.27       9.0  30/12/2024
# 3032      2696                  Laptop  $107.81       4.0  30/12/2024
# 3033      2913              Smartphone   $99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   $55.47       6.0  30/12/2024
#
#               categoria
# 0            Decoración
# 1            Decoración
# ...

# %% [markdown]
# 4- Introducción a Pandas: realizar un análisis exploratorio inicial de los DataFrames.

# %%
#info de cada DATA SETS
print("--------------------- Información detallada de cada DATASETS ---------------------")
print("Detalle de Ventas: ")
print("----------------------------------------------------------------------------------")
df_ventas.info()
print("----------------------------------------------------------------------------------")
print("Detalle de Clientes: ")
print("----------------------------------------------------------------------------------")
df_clientes.info()
print("----------------------------------------------------------------------------------")
print("Detalle de Marketing: ")
print("----------------------------------------------------------------------------------")
df_marketing.info()
# Out:
# --------------------- Información detallada de cada DATASETS ---------------------
# Detalle de Ventas:
# ----------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
#  2   precio       3033 non-null   object
#  3   cantidad     3033 non-null   float64
#  4   fecha_venta  3035 non-null   object
#  5   categoria    3035 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 142.4+ KB
# ----------------------------------------------------------------------------------
# Detalle de Clientes:
# ----------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# ...

# %%
#Mostramos los primeros datos de cada DATASETS
print("--------------------- Primeros datos de cada DATASETS ----------------------------")
print("Primeros datos de Ventas: ")
print("----------------------------------------------------------------------------------")
print(df_ventas.head())
print("----------------------------------------------------------------------------------")
print("Primeros datos de Clientes: ")
print("----------------------------------------------------------------------------------")
print(df_clientes.head())
print("----------------------------------------------------------------------------------")
print("Primeros datos de Marketing: ")
print("----------------------------------------------------------------------------------")
print(df_marketing.head())
# Out:
# --------------------- Primeros datos de cada DATASETS ----------------------------
# Primeros datos de Ventas:
# ----------------------------------------------------------------------------------
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# ----------------------------------------------------------------------------------
# Primeros datos de Clientes:
# ----------------------------------------------------------------------------------
#    id_cliente               nombre  edad         ciudad  ingresos
# ...

# %%
#Mostramos los últimos datos de cada DATASETS
print("--------------------- Últimos datos de cada DATASETS ----------------------------")
print("Últimos datos de Ventas: ")
print("----------------------------------------------------------------------------------")
print(df_ventas.tail())
print("----------------------------------------------------------------------------------")
print("Últimos datos de Clientes: ")
print("----------------------------------------------------------------------------------")
print(df_clientes.tail())
print("----------------------------------------------------------------------------------")
print("Últimos datos de Marketing: ")
print("----------------------------------------------------------------------------------")
print(df_marketing.tail())
# Out:
# --------------------- Últimos datos de cada DATASETS ----------------------------
# Últimos datos de Ventas:
# ----------------------------------------------------------------------------------
#       id_venta                producto   precio  cantidad fecha_venta  \
# 3030      1837         Horno eléctrico  $104.12       9.0  30/12/2024
# 3031      2276                  Laptop   $85.27       9.0  30/12/2024
# 3032      2696                  Laptop  $107.81       4.0  30/12/2024
# 3033      2913              Smartphone   $99.85       7.0  30/12/2024
# 3034      2930  Consola de videojuegos   $55.47       6.0  30/12/2024
#
#               categoria
# 3030  Electrodomésticos
# 3031        Electrónica
# 3032        Electrónica
# 3033        Electrónica
# 3034        Electrónica
# ----------------------------------------------------------------------------------
# Últimos datos de Clientes:
# ----------------------------------------------------------------------------------
# ...

# %%
#Información estadistica de cada DATASETS
print("--------------------- Información estadistica de cada DATASETS ---------------------")
print("Información estadistica de Ventas: ")
print("----------------------------------------------------------------------------------")
print(df_ventas.describe())
print("----------------------------------------------------------------------------------")
print("Información estadistica de Clientes: ")
print("----------------------------------------------------------------------------------")
print(df_clientes.describe())
print("----------------------------------------------------------------------------------")
print("Información estadistica de Marketing: ")
print("----------------------------------------------------------------------------------")
print(df_marketing.describe())
# Out:
# --------------------- Información estadistica de cada DATASETS ---------------------
# Información estadistica de Ventas:
# ----------------------------------------------------------------------------------
#           id_venta     cantidad
# count  3035.000000  3033.000000
# mean   1499.851400     6.496538
# std     866.465379     3.457250
# min       1.000000     1.000000
# 25%     748.500000     3.000000
# 50%    1502.000000     7.000000
# 75%    2249.500000     9.000000
# max    3000.000000    12.000000
# ----------------------------------------------------------------------------------
# Información estadistica de Clientes:
# ----------------------------------------------------------------------------------
#        id_cliente        edad      ingresos
# count  567.000000  567.000000    567.000000
# mean   284.000000   37.940035  34668.739012
# std    163.823075   10.202885  12974.531446
# min      1.000000   20.000000    170.290000
# 25%    142.500000   30.000000  26015.240000
# ...

# %%
#Mostramos tipo de datos de cada DATASETS
print("--------------------- Tipo de datos de cada DATASETS -----------------------------")
print("Tipo de datos de Ventas: ")
print("----------------------------------------------------------------------------------")
print(df_ventas.dtypes)
print("----------------------------------------------------------------------------------")
print("Tipo de datos de Clientes: ")
print("----------------------------------------------------------------------------------")
print(df_clientes.dtypes)
print("----------------------------------------------------------------------------------")
print("Tipo de datos de Marketing: ")
print("----------------------------------------------------------------------------------")
print(df_marketing.dtypes)
display(df_ventas.head())
# Out:
# --------------------- Tipo de datos de cada DATASETS -----------------------------
# Tipo de datos de Ventas:
# ----------------------------------------------------------------------------------
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
# ----------------------------------------------------------------------------------
# Tipo de datos de Clientes:
# ----------------------------------------------------------------------------------
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
# ----------------------------------------------------------------------------------
# Tipo de datos de Marketing:
# ----------------------------------------------------------------------------------
# id_campanha       int64
# producto         object
# canal            object
# ...

# %%
#Mostramos dimensión del DATASETS (Filas, columnas)
print("--------------------- Dimensiones de cada DATASETS -----------------------------")
print("Dimensiones de Ventas: ")
print("----------------------------------------------------------------------------------")
print(df_ventas.shape)
print("----------------------------------------------------------------------------------")
print("Dimensiones de Clientes: ")
print("----------------------------------------------------------------------------------")
print(df_clientes.shape)
print("----------------------------------------------------------------------------------")
print("Dimensiones de Marketing: ")
print("----------------------------------------------------------------------------------")
print(df_marketing.shape)
# Out:
# --------------------- Dimensiones de cada DATASETS -----------------------------
# Dimensiones de Ventas:
# ----------------------------------------------------------------------------------
# (3035, 6)
# ----------------------------------------------------------------------------------
# Dimensiones de Clientes:
# ----------------------------------------------------------------------------------
# (567, 5)
# ----------------------------------------------------------------------------------
# Dimensiones de Marketing:
# ----------------------------------------------------------------------------------
# (90, 6)

# %% [markdown]
# 5- Calidad de Datos: Identificar valores nulos y duplicados en los conjuntos de datos. Documentar el estado inicial de los datos.

# %%
#Identificamos duplicados en cada DATASETS, considerando que el primer valor es correcto y los que se repiten, son sus duplicados.
print("--------------------- Duplicados de cada DATASETS -----------------------------")
print("Ventas: ")
print("----------------------------------------------------------------------------------")
print(f"Cantdidad de filas duplicadas: {df_ventas.duplicated(keep=False).sum()}")
print("----------------------------------------------------------------------------------")
print("Clientes: ")
print("----------------------------------------------------------------------------------")
print(f"Cantidad de filas duplicadas: {df_clientes.duplicated().sum()}")
print("----------------------------------------------------------------------------------")
print("Marketing: ")
print("----------------------------------------------------------------------------------")
print(f"Cantidad de filas duplicadas: {df_marketing.duplicated().sum()}")
# Out:
# --------------------- Duplicados de cada DATASETS -----------------------------
# Ventas:
# ----------------------------------------------------------------------------------
# Cantdidad de filas duplicadas: 70
# ----------------------------------------------------------------------------------
# Clientes:
# ----------------------------------------------------------------------------------
# Cantidad de filas duplicadas: 0
# ----------------------------------------------------------------------------------
# Marketing:
# ----------------------------------------------------------------------------------
# Cantidad de filas duplicadas: 0

# %%
#DEF para mostrar contar los duplicados y mostrar los datos filtrados:
def calidad(df,nombre,id):
  print("Valores duplicados de la table",nombre)
  print("-")
  print(f"Cantidad de filas duplicadas: {df.duplicated(keep=False).sum()}")
  print("-----------------------------------------------")
  #contar duplicados por id de cada df
  print(f"Cantidad de filas duplicadas por {id}: {df.duplicated(keep=False).sum()}")
  print("-----------------------------------------------")
  #Armar una tabla filtrando los valores duplicados para mostrarlos
  duplicados = (df[df[id].duplicated(keep=False)][id].value_counts().sort_values(ascending=False))

  display(duplicados.head(10))
  print("-------------------------------------------------")

# %%
#Ejecucion de nuestro DEF
calidad(df_ventas, "Ventas", "id_venta")
calidad(df_clientes, "Clientes", "id_cliente")
calidad(df_marketing, "Marketing", "id_campanha")
# Out:
# Valores duplicados de la table Ventas
# -
# Cantidad de filas duplicadas: 70
# -----------------------------------------------
# Cantidad de filas duplicadas por id_venta: 70
# -----------------------------------------------
# id_venta
# 56      2
# 421     2
# 424     2
# 1868    2
# 2545    2
# 2778    2
# 145     2
# 300     2
# 439     2
# 906     2
# Name: count, dtype: int64
# -------------------------------------------------
# Valores duplicados de la table Clientes
# -
# Cantidad de filas duplicadas: 0
# -----------------------------------------------
# Cantidad de filas duplicadas por id_cliente: 0
# -----------------------------------------------
# Series([], Name: count, dtype: int64)
# -------------------------------------------------
# Valores duplicados de la table Marketing
# -
# Cantidad de filas duplicadas: 0
# -----------------------------------------------
# Cantidad de filas duplicadas por id_campanha: 0
# -----------------------------------------------
# ...

# %%
#identificar valores nulos en cada datasets
print("--------------------- Valores nulos de cada DATASETS -----------------------------")
print("Valores nulos de Ventas: ")
print("----------------------------------------------------------------------------------")
print(df_ventas.isnull().sum())
print("----------------------------------------------------------------------------------")
print("Valores nulos de Clientes: ")
print("----------------------------------------------------------------------------------")
print(df_clientes.isnull().sum())
print("----------------------------------------------------------------------------------")
print("Valores nulos de Marketing: ")
print("----------------------------------------------------------------------------------")
print(df_marketing.isnull().sum())
# Out:
# --------------------- Valores nulos de cada DATASETS -----------------------------
# Valores nulos de Ventas:
# ----------------------------------------------------------------------------------
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
# ----------------------------------------------------------------------------------
# Valores nulos de Clientes:
# ----------------------------------------------------------------------------------
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
# ----------------------------------------------------------------------------------
# Valores nulos de Marketing:
# ----------------------------------------------------------------------------------
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64

# %%
#Detectamos valores faltantes
print("--------------------- Valores faltantes de cada DATASETS -----------------------------")
print("Valores faltantes de Ventas: ")
print("----------------------------------------------------------------------------------")
print(df_ventas.isna().sum())
print("----------------------------------------------------------------------------------")
print("Valores faltantes de Clientes: ")
print("----------------------------------------------------------------------------------")
print(df_clientes.isna().sum())
print("----------------------------------------------------------------------------------")
print("Valores faltantes de Marketing: ")
print("----------------------------------------------------------------------------------")
print(df_marketing.isna().sum())
# Out:
# --------------------- Valores faltantes de cada DATASETS -----------------------------
# Valores faltantes de Ventas:
# ----------------------------------------------------------------------------------
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
# ----------------------------------------------------------------------------------
# Valores faltantes de Clientes:
# ----------------------------------------------------------------------------------
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
# ----------------------------------------------------------------------------------
# Valores faltantes de Marketing:
# ----------------------------------------------------------------------------------
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64

# %% [markdown]
# 6 - Limpieza de datos

# %%
#Copia de cada DataFrame
df_ventas_clean = df_ventas.copy()
df_clientes_clean = df_clientes.copy()
df_marketing_clean = df_marketing.copy()
#eliminar duplicados de cada DF
df_ventas_clean= df_ventas_clean.drop_duplicates()
df_clientes_clean= df_clientes_clean.drop_duplicates()
df_marketing_clean= df_marketing_clean.drop_duplicates()
print("Información de df_ventas_clean después de eliminar duplicados:")
df_ventas_clean.info()
print("\nInformación de df_clientes_clean después de eliminar duplicados:")
df_clientes_clean.info()
print("\nInformación de df_marketing_clean después de eliminar duplicados:")
df_marketing_clean.info()
print("\nCantidad de duplicados en df_ventas_clean:")
print(df_ventas_clean.duplicated().sum())
# Out:
# Información de df_ventas_clean después de eliminar duplicados:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3000 non-null   int64
#  1   producto     3000 non-null   object
#  2   precio       2998 non-null   object
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  3000 non-null   object
#  5   categoria    3000 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 164.1+ KB
#
# Información de df_clientes_clean después de eliminar duplicados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
# ...

# %%
#buscar columnas precios / costo / ingresos y eliminar signo $  - espacios
df_ventas_clean['precio'] = df_ventas_clean['precio'].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False).str.strip()
df_clientes_clean['ingresos'] = df_clientes_clean['ingresos'].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False).str.strip()
df_marketing_clean['costo'] = df_marketing_clean['costo'].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False).str.strip()
print("datos de la columna precio: ")
df_ventas_clean.info()
print("----------------------------------------------------------------------------------")
print(df_ventas_clean['precio'].head(5).sort_values(ascending=True))
print(df_clientes_clean['ingresos'].head(5).sort_values(ascending=True))
print(df_marketing_clean['costo'].head(5).sort_values(ascending=True))
#
#
# Out:
# datos de la columna precio:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3000 non-null   int64
#  1   producto     3000 non-null   object
#  2   precio       3000 non-null   object
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  3000 non-null   object
#  5   categoria    3000 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 164.1+ KB
# ----------------------------------------------------------------------------------
# 1    105.10
# 4    106.21
# 3    114.35
# 0     69.94
# 2     97.96
# Name: precio, dtype: object
# 1    24735.04
# 3    27647.96
# 4    28245.65
# 2    35744.85
# 0    42294.68
# Name: ingresos, dtype: object
# 1     3.4
# 4    4.25
# 0    4.81
# 2    5.54
# 3    6.37
# Name: costo, dtype: object

# %%
#Transformamos las columnas precio, ingresos y costo de nuestro dataframe en columna precio númerico.
df_ventas_clean['precio'] = pd.to_numeric(df_ventas_clean['precio'], errors='coerce')
df_clientes_clean['ingresos'] = pd.to_numeric(df_clientes_clean['ingresos'], errors='coerce')
df_marketing_clean['costo'] = pd.to_numeric(df_marketing_clean['costo'], errors='coerce')

# %%
#Limpiar texto de columnas tipo string
#borramos los espacios - convertimos a tipo string - convertimos las expresiones regulares - reempleazamos los espacios y convertimos los nombres propios con mayusculas las iniciales.
#Ventas
for col in df_ventas_clean.select_dtypes(include=['object']).columns:
  df_ventas_clean[col] = df_ventas_clean[col].astype(str).str.strip().replace(r"[\u200b\t\r\n]", "", regex=True).str.replace(" +", " ", regex=True).str.title()
#Clientes
for col in df_clientes_clean.select_dtypes(include=['object']).columns:
  df_clientes_clean[col] = df_clientes_clean[col].astype(str).str.strip().replace(r"[\u200b\t\r\n]", "", regex=True).str.replace(" +", " ", regex=True).str.title()
#Marketing
for col in df_marketing_clean.select_dtypes(include=['object']).columns:
  df_marketing_clean[col] = df_marketing_clean[col].astype(str).str.strip().replace(r"[\u200b\t\r\n]", "", regex=True).str.replace(" +", " ", regex=True).str.title()

# %%
print(df_ventas_clean.info())
print(df_ventas_clean.head())
print(df_clientes_clean.info())
print(df_clientes_clean.head())
print(df_marketing_clean.info())
print(df_marketing_clean.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3000 non-null   int64
#  1   producto     3000 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  3000 non-null   object
#  5   categoria    3000 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 164.1+ KB
# None
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94       5.0  02/01/2024
# 1       811    Lámpara De Mesa  105.10       5.0  02/01/2024
# 2      1156           Secadora   97.96       3.0  02/01/2024
# 3      1372           Heladera  114.35       8.0  02/01/2024
# 4      1546           Secadora  106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# ...

# %%
#Transformar y normalizar las columnas fechas de cada dataframe
for df in [df_ventas_clean,df_clientes_clean,df_marketing_clean]:
  for col in df.columns:
    if 'fecha' in col.lower():
      df[col] = pd.to_datetime(df[col], errors='coerce',dayfirst=True)

# %%
print(df_ventas_clean.info())
print(df_ventas_clean.head())
print(df_clientes_clean.info())
print(df_clientes_clean.head())
print(df_marketing_clean.info())
print(df_marketing_clean.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3000 non-null   int64
#  1   producto     3000 non-null   object
#  2   precio       2998 non-null   float64
#  3   cantidad     2998 non-null   float64
#  4   fecha_venta  3000 non-null   datetime64[ns]
#  5   categoria    3000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 164.1+ KB
# None
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94       5.0  2024-01-02
# 1       811    Lámpara De Mesa  105.10       5.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
# 3      1372           Heladera  114.35       8.0  2024-01-02
# 4      1546           Secadora  106.21       4.0  2024-01-02
#
#            categoria
# 0         Decoración
# ...

# %%
# guardamos el DATAFRAME limpio en un nuevo CSV
df_ventas_clean.to_csv('/content/drive/MyDrive/datasets/ventas_clean.csv', index=False)
df_clientes_clean.to_csv('/content/drive/MyDrive/datasets/clientes_clean.csv', index=False)
df_marketing_clean.to_csv('/content/drive/MyDrive/datasets/marketing_clean.csv', index=False)

# %%
display(df_ventas_clean.select_dtypes(include=['object']).columns)
# Out:
# Index(['producto', 'categoria'], dtype='object')

# %% [markdown]
# 7. Transformación de Datos

# %%
#muestra de productos con alto rendimiento
8#Agregar columna venta en df de ventas para medir metricas
df_ventas_metricas = df_ventas_clean.copy()
df_ventas_metricas['Ventas']=df_ventas_clean['precio']*df_ventas_clean['cantidad']
display(df_ventas_metricas.head(10).sort_values(by='Ventas',ascending=False))
8
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 3      1372           Heladera  114.35       8.0  2024-01-02
# 8       318  Rincón De Plantas   79.86      11.0  2024-01-03
# 7      2959          Proyector   88.17       9.0  2024-01-02
# 9       419         Candelabro   66.11       8.0  2024-01-03
# 1       811    Lámpara De Mesa  105.10       5.0  2024-01-02
# 4      1546           Secadora  106.21       4.0  2024-01-02
# 0       792  Cuadro Decorativo   69.94       5.0  2024-01-02
# 5      1697    Horno Eléctrico   35.35       9.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
# 6      1710   Plancha De Vapor   65.43       2.0  2024-01-02
#
#            categoria  Ventas
# 3  Electrodomésticos  914.80
# 8         Decoración  878.46
# 7        Electrónica  793.53
# 9         Decoración  528.88
# 1         Decoración  525.50
# 4  Electrodomésticos  424.84
# 0         Decoración  349.70
# 5  Electrodomésticos  318.15
# ...

# %% [markdown]
# # 8. Agregación

# %%
# Resumir las ventas por categoría de producto y analizar los ingresos generados.
# Resumen  de metricas
resumen_metricas= (
    df_ventas_metricas
    .groupby(by='producto')
      .agg(
        total_ventas=('Ventas','sum'),
        promedio_ventas=('Ventas','mean'),
        cantidades_vendidas=('cantidad','sum'),
        precio_promedio = ('precio','mean'),
        registro=('Ventas','size')

        ).sort_values(by='total_ventas',ascending=False)


    )
display(resumen_metricas)
#
# Out:
#                         total_ventas  promedio_ventas  cantidades_vendidas  \
# producto
# Lámpara De Mesa             82276.38       467.479432               1112.0
# Auriculares                 74175.58       518.710350                958.0
# Microondas                  72562.89       537.502889                912.0
# Cafetera                    59607.31       509.464188                765.0
# Cuadro Decorativo           54297.60       542.976000                726.0
# Smartphone                  54132.44       535.964752                665.0
# Secadora                    52115.45       521.154500                696.0
# Jarrón Decorativo           51130.88       511.308800                672.0
# Batidora                    50979.20       509.792000                672.0
# Rincón De Plantas           50456.45       499.568812                691.0
# Freidora Eléctrica          50155.15       501.551500                630.0
# ...

# %%
#Top de ventas
#percentil de 80%
p80=resumen_metricas['total_ventas'].quantile(0.8, interpolation='linear')

#filtro por top de ventas
top_ventas = (
        resumen_metricas[resumen_metricas['total_ventas'] >= p80]
        .sort_values(by='total_ventas', ascending=False)
    )

p80_float = f"{float(p80):,.2f}"
print(f"Valor del percentil de 80: {p80_float}")
display(p80_float)
display(top_ventas)
# Out:
# Valor del percentil de 80: 52,518.85
# '52,518.85'
#                    total_ventas  promedio_ventas  cantidades_vendidas  \
# producto
# Lámpara De Mesa        82276.38       467.479432               1112.0
# Auriculares            74175.58       518.710350                958.0
# Microondas             72562.89       537.502889                912.0
# Cafetera               59607.31       509.464188                765.0
# Cuadro Decorativo      54297.60       542.976000                726.0
# Smartphone             54132.44       535.964752                665.0
#
#                    precio_promedio  registro
# producto
# Lámpara De Mesa          72.720625       176
# Auriculares              76.302727       143
# Microondas               79.176000       135
# Cafetera                 79.046581       117
# Cuadro Decorativo        74.578000       100
# Smartphone               81.398416       101

# %% [markdown]
# #9. Integración de Datos

# %%
# : Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.
# como existen varios costos del producto en la tabla de marketing, los agrupo por producto y sumo los costos.
#agrupar df marketing clean por producto y sumar costos
df_filtro_mkt = df_marketing_clean.groupby('producto')['costo'].sum().reset_index()
comb_tablas = pd.merge(top_ventas, df_filtro_mkt, on='producto', how='left')
#combinar con merge la tabla top ventas con filtro pero multimplicar cantidades vendidas con costo

#display(df_marketing_clean)
#display(df_filtro_mkt)
display(comb_tablas)
# Out:
#             producto  total_ventas  promedio_ventas  cantidades_vendidas  \
# 0    Lámpara De Mesa      82276.38       467.479432               1112.0
# 1        Auriculares      74175.58       518.710350                958.0
# 2         Microondas      72562.89       537.502889                912.0
# 3           Cafetera      59607.31       509.464188                765.0
# 4  Cuadro Decorativo      54297.60       542.976000                726.0
# 5         Smartphone      54132.44       535.964752                665.0
#
#    precio_promedio  registro  costo
# 0        72.720625       176  15.93
# 1        76.302727       143  15.24
# 2        79.176000       135  14.19
# 3        79.046581       117  18.16
# 4        74.578000       100  15.85
# 5        81.398416       101  15.80
